# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
# define procedure here
import numpy as np
def check_input(matrix):
  for row in matrix:
            for item in row:
                if type(item) != int:
                    return False
  for row in matrix:
      if (len(row) != len(set(row))):
          return False
    
  transpose = np.transpose(matrix)
  for col in transpose:
      if (len(col) != len(set(col))):
          return False
    
  return True

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("StudentMarkSheet.csv")
print(data)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
print("Before", len(data))
data=data.dropna()
print("After" , len(data))
# Out:
# Before 200
# After 196

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
rows = "James Walker"
columns= "Student name"
data.loc[data[columns]==rows]
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
import matplotlib.pyplot as plt
import numpy as np
biology = data[['Exam name', 'Marks']]
biology=biology.loc[data['Exam name']=='Biology']
totalmarks=biology.loc['Marks']=biology.sum(numeric_only=True,axis=0)
rows=len(biology)
AverageB=totalmarks/rows

print("Biology average ",(AverageB))

chemistry = data[['Exam name', 'Marks']]
chemistry=chemistry.loc[data['Exam name']=='Chemistry']
totalmarks=chemistry.loc['Marks']=chemistry.sum(numeric_only=True,axis=0)
rows=len(chemistry)
AverageC=totalmarks/rows
print("Chemistry average ",(AverageC))

mathematics = data[['Exam name', 'Marks']]
mathematics=mathematics.loc[data['Exam name']=='Mathematics']
totalmarks=mathematics.loc['Marks']=mathematics.sum(numeric_only=True,axis=0)
rows=len(mathematics)
AverageM=totalmarks/rows
print("Mathematics average ",AverageM)

physics = data[['Exam name', 'Marks']]
physics=physics.loc[data['Exam name']=='Physics']
totalmarks=physics.loc['Marks']=physics.sum(numeric_only=True,axis=0)
rows=len(physics)
AveragePH=totalmarks/rows
print("Physics average ",(AveragePH))

philosophy = data[['Exam name', 'Marks']]
philosophy=philosophy.loc[data['Exam name']=='Philosophy']
totalmarks=philosophy.loc['Marks']=philosophy.sum(numeric_only=True,axis=0)
rows=len(philosophy)
AverageP=totalmarks/rows
print("Philosophy average ",(AverageP))

sociology = data[['Exam name', 'Marks']]
sociology=sociology.loc[data['Exam name']=='Sociology']
totalmarks=sociology.loc['Marks']=sociology.sum(numeric_only=True,axis=0)
rows=len(sociology)
AverageS=totalmarks/rows
print("Sociology average ",(AverageS))
# Out:
# Biology average  Marks    46.666667
# dtype: float64
# Chemistry average  Marks    48.703704
# dtype: float64
# Mathematics average  Marks    47.648649
# dtype: float64
# Physics average  Marks    49.409091
# dtype: float64
# Philosophy average  Marks    46.026316
# dtype: float64
# Sociology average  Marks    54.589744
# dtype: float64

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
x="biology"
y=AverageB
plt.bar(x,y)
x="mathematics"
y=AverageM
plt.bar(x,y)
x="philosophy"
y=AverageP
plt.bar(x,y)
x="physics"
y=AveragePH
plt.bar(x,y)
x="Chemistry"
y=AverageC
plt.bar(x,y)
x="Sociology"
y=AverageS
plt.bar(x,y)
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("CatData.csv")

data=data.dropna()
print(data)
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# independant variable:
Xi = np.array(data[["Mass (kg)"]])
Yi= np.array(data[["Tail Length (cm)"]]) # dependant variable:

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
#Total number of data points:
n=len(Xi)
    
    #X bar:
Xi_mean = Xi.mean()
    
    #Y bar:
Yi_mean = Yi.mean()
    
    #Sum of X:
S_Xi = (Xi).sum()


#Sum of Y:
S_Yi = (Yi).sum()
    
    #Sum of (X*Y) multiplied by n:
S_XiYi = ((Xi*Yi).sum())*n
print(S_XiYi)
    #Sum of X*Sum of Y:
S_Xi_S_Yi = S_Xi*S_Yi
    
    #Sum of (X*X) multiplied by n:
S_XiXi = ((Xi*Xi).sum())*n
print(S_XiXi)
    #Square of sum of X:
S_Xi_Square = S_Xi*S_Xi
# Out:
# 9988632.405
# 2139972.2325

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
#Slope:
slope = (S_XiYi- S_Xi_S_Yi) / (S_XiXi-S_Xi_Square)
    
    #Intercept:
intercept = Yi_mean - slope * Xi_mean
    
print("SLOPE" , slope)
print("INTERCEPTS" , intercept)
# Out:
# SLOPE 1.527591560803727
# INTERCEPTS 13.672955927266212

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.scatter(Xi,Yi)
plt.plot(data["Mass (kg)"],slope*data["Mass (kg)"]+intercept,color="red")

plt.xlabel("Mass (kg)")
plt.ylabel("Tail Length (cm)")
plt.show()
